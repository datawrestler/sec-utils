# %% [markdown]
# ### Secure SEC files

# %%
import os
import requests
import pandas as pd
from collections import namedtuple
from itertools import product
from azure.storage.blob.blockblobservice import BlockBlobService
import urllib.request
from keystore import get_key

from fastprogress import master_bar, progress_bar

# %%
save_dir = '/home/datawrestler/data/secfiles'

# %%
class Blob(object):
    
    def __init__(self, account_name='generalstorageblob2019',
                account_key=None):
        
        if account_key is None:
            account_key = get_key(key_type='BLOB')
        
        self.service = BlockBlobService(account_name=account_name,
                                       account_key=account_key)
        
        self.azure_store = {
            '10-K': 'annual',
            '10-K/A': 'annual',
            '10-Q': 'quarterly',
            '10-Q/A': 'quarterly',
            'DEF 14A': 'proxy',
            'DEFA14A': 'proxy'
        }
        
    def write_blob(self, ftype, fname, fpath):
        
        blobname = self.azure_store[ftype]
        
        if not self.service.exists(blobname):
            self.service.create_container(blobname)
            
        
        self.service.create_blob_from_path(blobname, 
                                          fname, 
                                          fpath)

# %%
from azure.storage.blob import BlockBlobService, PublicAccess
from azure.storage.blob.models import Blob

def run_sample():
    block_blob_service = BlockBlobService(account_name='your_name', account_key='your_key')
    container_name ='t1s'

    block_blob_service.copy_blob(container_name,'remoteURL.pdf','https://media.readthedocs.org/pdf/azure-storage/v0.20.3/azure-storage.pdf')


# Main method.
if __name__ == '__main__':
    run_sample()

# %%
blob = Blob()
name = '0000002178-13-000014.txt'
blob.service.make_blob_url('annual', name)
# Out:
# 'https://generalstorageblob2019.blob.core.windows.net/annual/0000002178-13-000014.txt'

# %%
sec_files = '/home/datawrestler/data/sec/annual'
files = os.listdir(sec_files)

# %%
from tqdm.auto import tqdm
for f in tqdm(files, total=len(files)):
    block_blob_service.create_blob_from_path(annual_name,
                                            f,
                                            os.path.join(sec_files, f))

# %%
# full index of SEC files
full_index_url = 'https://www.sec.gov/Archives/edgar/full-index/{year}/QTR{quarter}/form.idx'
base_url = 'https://www.sec.gov/Archives/{file_url}'

get_form = lambda x: str(requests.get(x).content)
formIDX = requests.get(full_index_url.format(year=2015, quarter=4)).content

# %%
def read_seen_files():
    master_record = pd.read_csv(os.path.join(save_dir, 'master_record.txt'), sep='\t', header=None
                                 )
    
    master_record.columns = ['Form Type', 
                        'Company Name',
                        'CIK',
                        'Date', 
                        'URL',
                        'download_path']

    seen_files = master_record['URL'].unique().tolist()
    
    return seen_files

seen_files = read_seen_files()

# %%
clean_lines = lambda x: [line.strip() for line in x.split('  ') if line.strip() != '']

def clean_form_lines(form):
    # split on newline char
    all_rows = []
    all_lines = form.split('\\n')
    for line in all_lines[1:]:
        line = clean_lines(line)
        if len(line) == 5:
            row = convert_line_to_row(line)
            all_rows.append(row)
    # drop header line ['Form Type', 'Company Name', 'CIK', 'Date Filed', 'File Name']
    return pd.concat(all_rows).iloc[1:]

def convert_line_to_row(line):
    return pd.DataFrame({'Form Type': line[0], 
                        'Company Name': line[1],
                        'CIK': line[2],
                        'Date Filed': line[3],
                        'File Name': line[4]}, index=[0])

# %%
def check_dir(file_type):
    # create dir for specified file type if it doesnt exist in save_dir
    path = os.path.join(save_dir, file_type)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

# %%
def write_master_record(line):
    master_record = os.path.join(save_dir, 'master_record.txt')
    with open(master_record, 'a') as file:
        file.write("\n{}".format(line)) # could be any text, appended @ the end of file
    file.close()

def download_sec_file(row, blob):
    try:
        form_type = row['Form Type']
        file_url = row['File Name']
        form_name = file_url.split('/')[-1]
        full_file_path = os.path.join(cache_dir, form_name)
        urllib.request.urlretrieve(base_url.format(file_url=file_url), full_file_path)
        blob.write_blob(form_type, form_name, full_file_path)
        # remove file from cache
        os.remove(full_file_path)
        return full_file_path
    except:
        return None

# %%
formdf = clean_form_lines(get_form(full_index_url.format(year=2015, quarter=4)))
formdf.head()

# %%
def subset_formdf(formdf, wanted_forms=None, seen_files=None):
    if wanted_forms is None:
        wanted_forms = [
            '10-K',
            '10-K/A',
            '10-Q', 
            '10-Q/A',
            'DEF 14A',
            'DEFA14A',
        ]
        
    
    out = formdf.loc[formdf['Form Type'].isin(wanted_forms)]
    
    if seen_files is not None:
        out = formdf.loc[~formdf['File Name'].isin(seen_files)]
    
    return out

# %%
quarters = list(range(1, 5))
years = list(reversed(list(range(2010, 2019))))
cache_dir = '.'

# %%
time = list(product(quarters, years))

# %%
from tqdm.auto import tqdm
for timeslice in tqdm(time, total=len(time)):
    qtr = timeslice[0]
    yr = timeslice[1]
# Out:
# HBox(children=(IntProgress(value=0, max=36), HTML(value='')))

# %%
mb = master_bar(list(product(quarters, years)))

alldf = []

for qtr, yr in mb:
    mb.first_bar.comment = 'Year - {} Quarter - {}'.format(yr, qtr)
    form_url = full_index_url.format(year=yr, quarter=qtr)
    form = get_form(form_url)
    formdf = clean_form_lines(form)
    # subset to correct form types
    formdf = subset_formdf(formdf, seen_files=seen_files)
    all_paths = []
    for index, row in progress_bar(formdf.iterrows(), total=formdf.shape[0], parent=mb):
        full_file_path = download_sec_file(row)
        form_type = row['Form Type']
        co_name = row['Company Name']
        cik = row['CIK']
        date_filed = row['Date Filed']
        file_name = row['File Name']
        line = '\t'.join([form_type, co_name, cik, date_filed, file_name, full_file_path])
        write_master_record(line)
        all_paths.append(full_file_path)
        mb.child.comment = 'Downloaded: {}'.format(co_name)

    formdf['full_file_path'] = all_paths
    alldf.append(formdf)

# %%
from sqlalchemy import create_engine

# %%
import pyodbc

# %%
from sqlalchemy import create_engine
import urllib

conn = get_key(key_type='SQL')
params = urllib.parse.quote_plus(conn)
engine = create_engine("mssql+pyodbc:///?odbc_connect=%s" % params)

# %%
import pandas as pd
import numpy as np

# get written log
log = pd.read_sql('select * from dbo.seclog', engine)

# %%
log
# Out:
#      form_type                                           co_name      cik  \
# 0         10-K            1347 Property Insurance Holdings, Inc.  1591890
# 1         10-K            1347 Property Insurance Holdings, Inc.  1591890
# 2         10-K            1347 Property Insurance Holdings, Inc.  1591890
# 3         10-K            1347 Property Insurance Holdings, Inc.  1591890
# 4         10-K            1347 Property Insurance Holdings, Inc.  1591890
# 5         10-K            1347 Property Insurance Holdings, Inc.  1591890
# 6         10-K            1347 Property Insurance Holdings, Inc.  1591890
# 7         10-K                          1ST CONSTITUTION BANCORP  1141807
# 8         10-K                                   1ST SOURCE CORP    34782
# 9         10-K                       1st FRANKLIN FINANCIAL CORP    38723
# 10        10-K                          22nd Century Group, Inc.  1347858
# 11        10-K                                          2U, Inc.  1459417
# 12        10-K                                   3D SYSTEMS CORP   910638
# 13        10-K                              3DX Industries, Inc.  1453122
# 14        10-K                              3DX Industries, Inc.  1453122
# 15        10-K                                             3M CO    66740
# 16        10-K                          3PEA INTERNATIONAL, INC.  1496443
# 17        10-K                                           5V Inc.  1504876
# 18        10-K                        8point3 Energy Partners LP  1635581
# 19        10-K                                   A. H. Belo Corp  1413898
# 20        10-K                                AAC Holdings, Inc.  1606180
# 21        10-K                                          AAON INC   824142
# 22        10-K                                       AARON'S INC   706688
# 23        10-K                      AB INTERNATIONAL GROUP CORP.  1605331
# 24        10-K                  AB Private Credit Investors Corp  1634452
# 25        10-K                               ABBOTT LABORATORIES     1800
# 26        10-K                          ABEONA THERAPEUTICS INC.   318306
# 27        10-K                            ABRAXAS PETROLEUM CORP   867665
# 28        10-K                              ABV CONSULTING, INC.  1607450
# 29        10-K                              ACACIA RESEARCH CORP   934549
# ...        ...                                               ...      ...
# 1716      10-K                          Exeo Entertainment, Inc.  1528760
# 1717      10-K                         ExlService Holdings, Inc.  1297989
# 1718      10-K                                     Expedia, Inc.  1324424
# 1719      10-K                       Express Scripts Holding Co.  1532063
# 1720      10-K                       Extended Stay America, Inc.  1581164
# 1721      10-K                                     Exterran Corp  1635881
# 1722      10-K                          Extra Space Storage Inc.  1289490
# 1723      10-K                        Extraction Oil & Gas, Inc.  1655020
# 1724      10-K                                     F&M BANK CORP   740806
# 1725      10-K                   FAIRMOUNT SANTROL HOLDINGS INC.  1010858
# 1726      10-K                       FAMOUS DAVES OF AMERICA INC  1021270
# 1727      10-K                       FARMERS & MERCHANTS BANCORP  1085913
# 1728      10-K                   FARMERS & MERCHANTS BANCORP INC   792966
# 1729      10-K                         FARMERS CAPITAL BANK CORP   713095
# 1730      10-K                   FARMERS NATIONAL BANC CORP /OH/   709337
# 1731      10-K                             FARO TECHNOLOGIES INC   917491
# 1732      10-K                                       FASTENAL CO   815556
# 1733      10-K                             FATE THERAPEUTICS INC  1434316
# 1734      10-K                         FAUQUIER BANKSHARES, INC.  1083643
# 1735      10-K                                 FB Financial Corp  1649749
# 1736      10-K                           FBL FINANCIAL GROUP INC  1012771
# 1737      10-K                      FCB FINANCIAL HOLDINGS, INC.  1476651
# 1738      10-K                FEDERAL AGRICULTURAL MORTGAGE CORP   845877
# 1739      10-K                   FEDERAL HOME LOAN MORTGAGE CORP  1026214
# 1740      10-K  FEDERAL NATIONAL MORTGAGE ASSOCIATION FANNIE MAE   310522
# 1741      10-K                   FEDERAL REALTY INVESTMENT TRUST    34903
# 1742      10-K                          FEDERAL SIGNAL CORP /DE/   277509
# 1743      10-K                      FEDERATED INVESTORS INC /PA/  1056288
# 1744      10-K                     FEDERATED NATIONAL HOLDING Co  1069996
# 1745      10-K                       FENNEC PHARMACEUTICALS INC.  1211583
#
#       date_filed                                    file_name success
# 0     2018-03-26  edgar/data/1591890/0001493152-18-003887.txt    None
# 1     2018-03-26  edgar/data/1591890/0001493152-18-003887.txt    None
# 2     2018-03-26  edgar/data/1591890/0001493152-18-003887.txt       1
# 3     2018-03-26  edgar/data/1591890/0001493152-18-003887.txt       1
# 4     2018-03-26  edgar/data/1591890/0001493152-18-003887.txt       1
# 5     2018-03-26  edgar/data/1591890/0001493152-18-003887.txt       1
# 6     2018-03-26  edgar/data/1591890/0001493152-18-003887.txt       1
# 7     2018-03-19  edgar/data/1141807/0001141807-18-000005.txt       1
# 8     2018-02-16    edgar/data/34782/0000034782-18-000033.txt       1
# 9     2018-03-30    edgar/data/38723/0001376474-18-000064.txt       1
# 10    2018-03-07  edgar/data/1347858/0001144204-18-013354.txt       1
# 11    2018-02-27  edgar/data/1459417/0001047469-18-001109.txt       1
# 12    2018-03-14   edgar/data/910638/0000910638-18-000006.txt       1
# 13    2018-01-17  edgar/data/1453122/0001594062-18-000008.txt       1
# 14    2018-01-17  edgar/data/1453122/0001594062-18-000012.txt       1
# 15    2018-02-08    edgar/data/66740/0001558370-18-000535.txt       1
# 16    2018-03-26  edgar/data/1496443/0001683168-18-000758.txt       1
# 17    2018-01-16  edgar/data/1504876/0001213900-18-000546.txt       1
# 18    2018-02-05  edgar/data/1635581/0001628280-18-001014.txt       1
# 19    2018-03-16  edgar/data/1413898/0001413898-18-000010.txt       1
# 20    2018-02-23  edgar/data/1606180/0001564590-18-003044.txt       1
# 21    2018-02-27   edgar/data/824142/0000824142-18-000021.txt       1
# 22    2018-03-01   edgar/data/706688/0000706688-18-000032.txt       1
# 23    2018-01-12  edgar/data/1605331/0001640334-18-000075.txt       1
# 24    2018-03-20  edgar/data/1634452/0001193125-18-089241.txt       1
# 25    2018-02-16     edgar/data/1800/0001047469-18-000856.txt       1
# 26    2018-03-16   edgar/data/318306/0001144204-18-015277.txt       1
# 27    2018-03-16   edgar/data/867665/0000867665-18-000014.txt       1
# 28    2018-03-19  edgar/data/1607450/0001640334-18-000475.txt       1
# 29    2018-03-07   edgar/data/934549/0000934549-18-000007.txt       1
# ...          ...                                          ...     ...
# 1716  2018-03-06  edgar/data/1528760/0001654954-18-002162.txt       1
# 1717  2018-02-27  edgar/data/1297989/0001297989-18-000002.txt       1
# 1718  2018-02-09  edgar/data/1324424/0001324424-18-000006.txt       1
# 1719  2018-02-27  edgar/data/1532063/0001532063-18-000004.txt       1
# 1720  2018-02-27  edgar/data/1581164/0001628280-18-002303.txt       1
# 1721  2018-02-28  edgar/data/1635881/0001635881-18-000012.txt       1
# 1722  2018-03-01  edgar/data/1289490/0001628280-18-002649.txt       1
# 1723  2018-02-27  edgar/data/1655020/0001655020-18-000027.txt       1
# 1724  2018-03-16   edgar/data/740806/0001654954-18-002674.txt       1
# 1725  2018-03-13  edgar/data/1010858/0001564590-18-005434.txt       1
# 1726  2018-03-05  edgar/data/1021270/0001021270-18-000006.txt       1
# 1727  2018-03-16  edgar/data/1085913/0001140361-18-013710.txt       1
# 1728  2018-02-28   edgar/data/792966/0001193125-18-062514.txt       1
# 1729  2018-03-12   edgar/data/713095/0001437749-18-004397.txt       1
# 1730  2018-03-06   edgar/data/709337/0001564590-18-004502.txt       1
# 1731  2018-02-21   edgar/data/917491/0000917491-18-000007.txt       1
# 1732  2018-02-05   edgar/data/815556/0000815556-18-000010.txt       1
# 1733  2018-03-05  edgar/data/1434316/0001564590-18-004394.txt       1
# 1734  2018-03-29  edgar/data/1083643/0001083643-18-000009.txt       1
# 1735  2018-03-16  edgar/data/1649749/0001564590-18-006079.txt       1
# 1736  2018-03-01  edgar/data/1012771/0001012771-18-000006.txt       1
# 1737  2018-02-23  edgar/data/1476651/0001476651-18-000084.txt       1
# 1738  2018-03-08   edgar/data/845877/0000845877-18-000017.txt       1
# 1739  2018-02-15  edgar/data/1026214/0001026214-18-000020.txt       1
# 1740  2018-02-14   edgar/data/310522/0000310522-18-000107.txt       1
# 1741  2018-02-13    edgar/data/34903/0000034903-18-000009.txt       1
# 1742  2018-02-28   edgar/data/277509/0000277509-18-000006.txt       1
# 1743  2018-02-23  edgar/data/1056288/0001056288-18-000004.txt       1
# 1744  2018-03-13  edgar/data/1069996/0001069996-18-000003.txt       0
# 1745  2018-03-28  edgar/data/1211583/0001144204-18-017571.txt       0
#
# [1746 rows x 6 columns]
